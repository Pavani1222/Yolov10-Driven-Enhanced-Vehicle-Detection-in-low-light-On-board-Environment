# %%
from ultralytics import YOLO
import cv2
import os
from pathlib import Path

# %%
# Set dataset directory path
dataset_dir = "E:/TR/NEW_NIGHT/MAIN_CODE"

# Example structure
train_images = os.path.join(dataset_dir, "train/images")
val_images = os.path.join(dataset_dir, "valid/images")
train_labels = os.path.join(dataset_dir, "train/labels")
val_labels = os.path.join(dataset_dir, "valid/labels")

# %%
# Create the YAML file for the dataset
yaml_content = """

train: E:/TR/NEW_NIGHT/MAIN_CODE/train/images
val: E:/TR/NEW_NIGHT/MAIN_CODE/valid/images
test: E:/TR/NEW_NIGHT/MAIN_CODE/test/images

nc: 12
names: ['Bicycle', 'Bus', 'Car', 'Cat', 'Dog', 'Light', 'Motorcycle', 'Person', 'Pothole', 'Sign', 'Tree', 'Truck']

"""

# Save the YAML file
with open("data.yaml", "w") as f:
    f.write(yaml_content)

# %%
# Initialize YOLOv8 model (e.g., yolov8n for Nano version)
model = YOLO('yolov10n.pt') 

# Or load a pretrained model like 'yolov8n.pt'
# Out:
# C:\Users\Main Python\anaconda3\lib\site-packages\ultralytics\nn\tasks.py:781: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(file, map_location="cpu")

# %%
### Train the YOLOv8 model
#model.train(data='data.yaml', epochs=50, imgsz=640, batch=26)
# ===============================
# 4. Train Model
# ===============================
# Train the YOLOv8/YOLOv10 model and save results on E drive
E:\TR\NEW_NIGHT\runs\train_run1\weights
model = YOLO('E:/TR/NEW_NIGHT/runs/train_run1/weights/best.pt') 
results = model.train(
    data="data.yaml",
    epochs=50,
    batch=26,
    imgsz=640,
    device="cpu",
    resume=True
   
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.209 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.50  Python-3.9.12 torch-2.5.1+cpu CPU (Intel Core(TM) i5-6500 3.20GHz)
# ...

# %%
# Evaluate the trained model on validation data
metrics = model.val()
print(metrics)

# %%
model_path = 'D:/SHIVAA/CODES/MARINE_DEBRIS/CODE/MAIN_CODE/runs/detect/train4/weights/best.pt'
model = YOLO(model_path)
results = model(source='D:/SHIVAA/CODES/MARINE_DEBRIS/CODE/MAIN_CODE/test/images', conf=0.25,save=True)

# %%
# !pip install ultralytics

# %%
# Export the trained model
model.export(format='onnx')  # Export to ONNX format

# %%
# !pip install opencv-contrib-python

# %%
#Image code


from ultralytics import YOLO
import cv2

# Load YOLO model
model = YOLO(r'D:/SHIVAA/CODES/MARINE_DEBRIS/CODE/MAIN_CODE/runs/detect/train4/weights/best.pt')

# Input and output image paths
input_image_path = r"D:/SHIVAA/CODES/MARINE_DEBRIS/CODE/MAIN_CODE/test/images/1bc7-iudfmpmn7245599_jpg.rf.616a393590ae0656d4754997ab8d5f0c.jpg"
output_image_path = r"D:/SHIVAA/CODES/MARINE_DEBRIS/CODE/MAIN_CODE/output.jpg"

# Load the image
image = cv2.imread(input_image_path)

# Perform detection
results = model.predict(image)

# Annotate detections
for result in results[0].boxes.data.tolist():
    x1, y1, x2, y2, conf, cls = result
    x1, y1, x2, y2 = map(int, (x1, y1, x2, y2))  # Bounding box coordinates
    label = f"{model.names[int(cls)]} {conf:.2f}"  # Label with confidence

    # Draw bounding box and label
    cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)  # Green box
    cv2.putText(image, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

# Save the output image
cv2.imwrite(output_image_path, image)
